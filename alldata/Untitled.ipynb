# %%
import pandas as pd
df=pd.read_csv('age.csv',encoding='cp949',index_col=0)
df.head()
# Out:
#                                 총인구수  연령구간인구수  2019년02월_계_0세
# 행정구역
# 서울특별시  (1100000000)          9770638    53738          53738
# 서울특별시 종로구 (1111000000)        152880      593            593
# 서울특별시 종로구 청운효자동(1111051500)    13010       66             66
# 서울특별시 종로구 사직동(1111053000)       9584       43             43
# 서울특별시 종로구 삼청동(1111054000)       2820        9              9

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.rc('font',family='Malgun Gothic')
df=pd.read_csv('age.csv',encoding='cp949',index_col=0)
df=df.div(df['총인구수'],axis=0)
del df['총인구수'],df['연령구간인구수']
name=input('원하는 지역의 이름을 입력해주세요 : ')
a=df.index.str.contains(name)
df2=df[a]
df.loc[np.power(df.sub(df2.iloc[0],axis=1),2).sum(axis=1).sort_values().index[:5]].T.plot()
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 :  양재1동
